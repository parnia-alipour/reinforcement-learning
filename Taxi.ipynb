# %%
import gymnasium

# %%
env=gymnasium.make('Taxi-v3').env

# %%
obs, info = env.reset()

# %%
env.render()

# %%
env.reset()
env.render()

# %%
env.action_space
# Out:
# Discrete(6)

# %%
env.observation_space
# Out:
# Discrete(500)

# %%
raw_env = env.unwrapped

# %%
state = raw_env.encode(2, 1, 2, 0)
state
# Out:
# 228

# %%
env.s=state
env.render()

# %%
print(raw_env.P[state])
# Out:
# {0: [(1.0, 328, -1, False)], 1: [(1.0, 128, -1, False)], 2: [(1.0, 248, -1, False)], 3: [(1.0, 208, -1, False)], 4: [(1.0, 228, -10, False)], 5: [(1.0, 228, -10, False)]}

# %%
print(raw_env.P[128])
# Out:
# {0: [(1.0, 228, -1, False)], 1: [(1.0, 28, -1, False)], 2: [(1.0, 128, -1, False)], 3: [(1.0, 108, -1, False)], 4: [(1.0, 128, -10, False)], 5: [(1.0, 128, -10, False)]}
